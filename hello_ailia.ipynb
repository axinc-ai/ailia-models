# %% [markdown]
# # Hello ailia SDK!

# %% [markdown]
# - [Open with Colab](https://colab.research.google.com/github/axinc-ai/ailia-models/blob/master/hello-ailia.ipynb)

# %% [markdown]
# In this tutorial, we install the ailia SDK and ailia MODELS, and perform object detection using yolox.

# %%
# !pip3 install ailia
# !git clone --depth 1 https://github.com/axinc-ai/ailia-models
# Out:
# Collecting ailia
#   Downloading ailia-1.3.0.3-py3-none-any.whl (47.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 6.7 MB/s eta 0:00:00
# Installing collected packages: ailia
# Successfully installed ailia-1.3.0.3
# Cloning into 'ailia-models'...
# remote: Enumerating objects: 3097, done.
# remote: Counting objects: 100% (3097/3097), done.
# remote: Compressing objects: 100% (2659/2659), done.
# remote: Total 3097 (delta 485), reused 2162 (delta 367), pack-reused 0
# Receiving objects: 100% (3097/3097), 622.63 MiB | 28.64 MiB/s, done.
# Resolving deltas: 100% (485/485), done.
# Updating files: 100% (2836/2836), done.

# %%
# light
# !pip3 install opencv-python numpy
# full
#!pip3 install -r ailia-models/requirements.txt
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)

# %%
# %cd ailia-models/object_detection/yolox
# !python3 yolox.py
# Out:
# /content/ailia-models/object_detection/yolox
#  INFO arg_utils.py (13) : Start!
#  INFO arg_utils.py (158) : env_id updated to 0
#  INFO arg_utils.py (163) : env_id: 0
#  INFO arg_utils.py (166) : CPU
#  INFO model_utils.py (74) : Downloading onnx file... (save path: yolox_s.opt.onnx)
#  INFO model_utils.py (80) :
#
#  INFO model_utils.py (82) : Downloading prototxt file... (save path: yolox_s.opt.onnx.prototxt)
#  INFO model_utils.py (88) :
#
#  INFO model_utils.py (89) : ONNX file and Prototxt file are prepared!
#  INFO license.py (114) : Download license file for ailia SDK.
#  INFO license.py (114) : Download license file for ailia SDK.
#  INFO license.py (77) : Welcome to ailia! The ailia SDK is a commercial library. Under certain conditions, it can be used free of charge; however, it is principally paid software. For details, please refer to https://ailia.ai/license/ .
#  INFO yolox.py (137) : Start inference...
# object_count=20
# + idx=0
#   category=0[ person ]
#   prob=0.9396765828132629
#   x=0.7634885311126709
#   y=0.6418798742159991
#   w=0.13833279609680177
#   h=0.3576602846244131
# + idx=1
#   category=0[ person ]
#   prob=0.916135311126709
#   x=0.6597650527954102
#   y=0.6959691293922389
#   w=0.0901834487915039
#   h=0.30208175730817194
# + idx=2
#   category=2[ car ]
#   prob=0.9160774946212769
#   x=0.0009107589721679688
#   y=0.6570675988712221
#   w=0.1844846487045288
#   h=0.16272760668830694
# + idx=3
#   category=0[ person ]
#   prob=0.8899269104003906
#   x=0.6157032489776612
#   y=0.6558713957737309
#   w=0.07102041244506836
#   h=0.3215789078546802
# + idx=4
#   category=0[ person ]
#   prob=0.8780717849731445
#   x=0.8913379669189453
#   y=0.681295976952208
#   w=0.0612030029296875
#   h=0.29001484902252056
# + idx=5
#   category=0[ person ]
#   prob=0.8659120202064514
#   x=0.25535874366760253
#   y=0.6904260339871259
#   w=0.06762733459472656
#   h=0.2587286004438087
# + idx=6
#   category=1[ bicycle ]
#   prob=0.8059049844741821
#   x=0.253412127494812
#   y=0.8039456219740317
#   w=0.06215662956237793
#   h=0.1881334188398621
# + idx=7
#   category=0[ person ]
#   prob=0.794460117816925
#   x=0.17626662254333497
#   y=0.6462986905809859
#   w=0.02435011863708496
#   h=0.09724576708296655
# + idx=8
#   category=0[ person ]
#   prob=0.7339480519294739
#   x=0.7131322383880615
#   y=0.6663265317818369
#   w=0.025017452239990235
#   h=0.10279136980083627
# + idx=9
#   category=0[ person ]
#   prob=0.7258288860321045
#   x=0.2595444917678833
#   y=0.6589680703033304
#   w=0.018172788619995116
#   h=0.07488784431851526
# + idx=10
#   category=26[ handbag ]
#   prob=0.6688534617424011
#   x=0.7642431259155273
#   y=0.8847502945734301
#   w=0.03393764495849609
#   h=0.11582939613593017
# + idx=11
#   category=0[ person ]
#   prob=0.6471939086914062
#   x=0.026179632544517516
#   y=0.629120087959397
#   w=0.020702999830245972
#   h=0.03417324012433979
# + idx=12
#   category=2[ car ]
#   prob=0.6337968707084656
#   x=0.00011698156595230103
#   y=0.7260906953766872
#   w=0.02783282846212387
#   h=0.11622956325190728
# + idx=13
#   category=0[ person ]
#   prob=0.5929746627807617
#   x=0.42935795783996583
#   y=0.649402099036275
#   w=0.01709470748901367
#   h=0.0699643417143486
# + idx=14
#   category=0[ person ]
#   prob=0.5922203660011292
#   x=0.20825986862182616
#   y=0.652649355606294
#   w=0.02245478630065918
#   h=0.09325541464935445
# + idx=15
#   category=0[ person ]
#   prob=0.5724209547042847
#   x=0.2982479572296143
#   y=0.654164990348995
#   w=0.018197107315063476
#   h=0.06542596234961855
# + idx=16
#   category=0[ person ]
#   prob=0.5568608045578003
#   x=0.15598011016845703
#   y=0.651894941016542
#   w=0.01880199909210205
#   h=0.059452970262984156
# + idx=17
#   category=0[ person ]
#   prob=0.5073506832122803
#   x=0.3724264621734619
#   y=0.6446834797030884
#   w=0.017729854583740233
#   h=0.06124347812133216
# + idx=18
#   category=0[ person ]
#   prob=0.4181171953678131
#   x=0.3586261510848999
#   y=0.6486900222133583
#   w=0.015104913711547851
#   h=0.05776963211561033
# + idx=19
#   category=0[ person ]
#   prob=0.4075894057750702
#   x=0.06371291279792786
#   y=0.6346805196412852
#   w=0.022706246376037596
#   h=0.025424008078418426
#  INFO yolox.py (163) : saved at : output.jpg
#  INFO yolox.py (172) : Script finished successfully.

# %%
from IPython import display
display.Image("output.jpg")
