# %% [markdown]
# # Hello GPT-SoVITS with ailia SDK!

# %% [markdown]
# - [Open with Colab](https://colab.research.google.com/github/axinc-ai/ailia-models/blob/master/audio_processing/gpt-sovits/colab.ipynb)

# %% [markdown]
# In this tutorial, we install the ailia SDK and ailia MODELS, and perform object detection using yolox.

# %%
# !pip3 install ailia
# !git clone --branch gpt-sovits --depth 1 https://github.com/axinc-ai/ailia-models
# Out:
# ...
#   Cloning https://github.com/axinc-ai/ailia-sdk-beta.git to /tmp/pip-req-build-_z86hk8c
#   Running command git clone --filter=blob:none --quiet https://github.com/axinc-ai/ailia-sdk-beta.git /tmp/pip-req-build-_z86hk8c
#   Resolved https://github.com/axinc-ai/ailia-sdk-beta.git to commit 4d4f1afea3b8ec70d65d353adade2a8c3f98bfc5
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ailia: filename=ailia-1.4.0.0-py3-none-any.whl size=54269361 sha256=5af2dd371f0f2dd1b4d6dcffc6f027564f763f6477d2e0f6bb42312ba6b8c71a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_f5hs7z5/wheels/a1/10/1d/ce12e63028c174357542f3260e9bca7ae546a6a4d8949df5cb
# Successfully built ailia
# ...
# Cloning into 'ailia-models'...
# remote: Enumerating objects: 3131, done.
# remote: Counting objects: 100% (3131/3131), done.
# remote: Compressing objects: 100% (2687/2687), done.
# remote: Total 3131 (delta 493), reused 2224 (delta 371), pack-reused 0
# ...

# %%
# light
# !pip3 install opencv-python numpy
# full
#!pip3 install -r ailia-models/requirements.txt
# audio
# !pip3 install -r ailia-models/audio_processing/gpt-sovits/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 29.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 25.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 63.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 78.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 kB 21.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941172 sha256=8639f2f0828ac97507a0ba3e73a7271c1f025c0114554ae75a565df9ef7811bb
#   Stored in directory: /root/.cache/pip/wheels/23/c8/c6/eed80894918490a175677414d40bd7c851413bbe03d4856c3c
# ...
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16258 sha256=5f0fc2c93c8579685168156a1d871ad212a6607fa23f798ecd83efa299b46b6d
# ...

# %% [markdown]
# 音声合成を行います。--ref_audioに参照する声色のファイル、--ref_textに声色のファイルで喋っている内容、-iに喋らせたい内容を指定します。

# %%
# !cd ailia-models/audio_processing/gpt-sovits && python3 gpt-sovits.py -e 0 -i "音声合成のテストを行なっています。" --ref_audio reference_audio_captured_by_ax.wav --ref_text "水をマレーシアから買わなくてはならない。"
# Out:
#  INFO arg_utils.py (13) : Start!
#  INFO arg_utils.py (163) : env_id: 0
#  INFO arg_utils.py (166) : CPU
#  INFO model_utils.py (74) : Downloading onnx file... (save path: cnhubert.onnx)
#  INFO model_utils.py (80) :
#
#  INFO model_utils.py (82) : Downloading prototxt file... (save path: cnhubert.onnx.prototxt)
#  INFO model_utils.py (88) :
#
#  INFO model_utils.py (89) : ONNX file and Prototxt file are prepared!
#  INFO model_utils.py (74) : Downloading onnx file... (save path: t2s_encoder.onnx)
#  INFO model_utils.py (80) :
#
#  INFO model_utils.py (82) : Downloading prototxt file... (save path: t2s_encoder.onnx.prototxt)
#  INFO model_utils.py (88) :
#
#  INFO model_utils.py (89) : ONNX file and Prototxt file are prepared!
#  INFO model_utils.py (74) : Downloading onnx file... (save path: t2s_fsdec.onnx)
#  INFO model_utils.py (80) :
#
#  INFO model_utils.py (82) : Downloading prototxt file... (save path: t2s_fsdec.onnx.prototxt)
#  INFO model_utils.py (88) :
#
# ...

# %%
from IPython import display
display.Audio("ailia-models/audio_processing/gpt-sovits/output.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
